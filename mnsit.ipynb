# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/train.csv')

# %%
df.sample(5)
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 8316       4       0       0       0       0       0       0       0       0
# 31534      8       0       0       0       0       0       0       0       0
# 35864      9       0       0       0       0       0       0       0       0
# 11354      3       0       0       0       0       0       0       0       0
# 9308       4       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 8316        0  ...         0         0         0         0         0
# 31534       0  ...         0         0         0         0         0
# 35864       0  ...         0         0         0         0         0
# 11354       0  ...         0         0         0         0         0
# 9308        0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 8316          0         0         0         0         0
# 31534         0         0         0         0         0
# 35864         0         0         0         0         0
# 11354         0         0         0         0         0
# 9308          0         0         0         0         0
#
# [5 rows x 785 columns]

# %%
plt.imshow(df.iloc[1820,1:].values.reshape(28,28))

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (33600, 784)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
import time
start =time.time()
y_pred=knn.predict(x_test)

print(time.time()-start)
# Out:
# 18.018985509872437

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9648809523809524

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_test= scaler.fit_transform(x_test)
x_train=scaler.fit_transform(x_train)

# %%
#from PCA
from sklearn.decomposition import PCA
pca=PCA(n_components=150)

# %%
x_train_trf=pca.fit_transform(x_train)
x_test_trf=pca.transform(x_test)

# %%
x_train_trf.shape
# Out:
# (33600, 150)

# %%
sam=pd.read_csv('/content/test.csv')

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(x,y)
ypd=knn.predict(sam)
# accuracy_score(y)
# accuracy_score(y,ypd)

# %%
knn.fit(x_train_trf,y_train)
yprd=knn.predict(x_test_trf)
print(accuracy_score(y_test,yprd))
# Out:
# 0.9534523809523809

# %%
sam.sample(5)
# Out:
#        pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 24406       0       0       0       0       0       0       0       0       0
# 26014       0       0       0       0       0       0       0       0       0
# 19005       0       0       0       0       0       0       0       0       0
# 23317       0       0       0       0       0       0       0       0       0
# 15341       0       0       0       0       0       0       0       0       0
#
#        pixel9  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 24406       0  ...         0         0         0         0         0
# 26014       0  ...         0         0         0         0         0
# 19005       0  ...         0         0         0         0         0
# 23317       0  ...         0         0         0         0         0
# 15341       0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 24406         0         0         0         0         0
# 26014         0         0         0         0         0
# 19005         0         0         0         0         0
# 23317         0         0         0         0         0
# 15341         0         0         0         0         0
#
# [5 rows x 784 columns]
